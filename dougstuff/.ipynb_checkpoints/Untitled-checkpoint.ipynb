# %%
import pandas as pd

# %%
df = pd.read_csv("r-joined.csv")

# %%
df.shape
# Out:
# (8098, 3178)

# %%
df.head()
# Out:
#    Unnamed: 0  CASEID        V2  V3    V4  V5  V6  V7  V8  V9   ...    \
# 0           1   10001  60080192   1  8128   9  28  90   9  28   ...
# 1           2   10002  16030048   1  3941  10   1  90  10   1   ...
# 2           3   10003  74070592   1  7813  10   5  90  10   5   ...
# 3           4   10004  74030720   1  7813  10  10  90  10  10   ...
# 4           5   10005   4180080   1  9018  10  10  90  10  10   ...
#
#    OLDP2FWT  P2WTV2  PVT   PVTRT  P2WTV3.y  EMP  EMPST  EMPW  EMPH  EMPOTH
# 0       NaN     NaN    1  0.6016       NaN    2      0     1     0       0
# 1       NaN     NaN    0  2.1321       NaN    2      0     1     0       0
# 2       NaN     NaN    0  1.3077       NaN    2      0     1     0       0
# 3       NaN     NaN    1  0.7391       NaN    3      0     0     1       0
# 4       NaN     NaN    0  1.2613       NaN    2      0     1     0       0
#
# [5 rows x 3178 columns]

# %%
import numpy as np

# %%
df.drop(columns=[df.columns.tolist()[0]], inplace=True)

# %%
df.shape
# Out:
# (8098, 3177)

# %%
def check_n_vars (a_df, n):
    """Pick n of the variables in the data frame and summarize values"""
    cols = a_df.columns.tolist()
    selection = np.random.randint(0, a_df.shape[1], n)
    for idx in selection:
        col = cols[idx]
        print(col)
        print(a_df[col].value_counts())
        print(f"Count of pandas missing values: {sum(a_df[col].isna())}")

# %%
check_n_vars(df, 100)
# Out:
# V4225
# 0    5955
# 9    2142
# 1       1
# Name: V4225, dtype: int64
# Count of pandas missing values: 0
# V3135
# 0     8088
# 19       3
# 16       2
# 22       1
# 18       1
# 14       1
# 37       1
# 12       1
# Name: V3135, dtype: int64
# Count of pandas missing values: 0
# V7223
# 0    5907
# 9    2144
# 2      39
# 1       8
# Name: V7223, dtype: int64
# Count of pandas missing values: 0
# V3933
# 0    8094
# 9       4
# Name: V3933, dtype: int64
# Count of pandas missing values: 0
# V3745
# 0     8028
# 25       8
# 20       7
# 30       6
# 21       4
# 33       4
# 27       4
# 17       3
# 24       3
# 36       3
# 41       3
# 40       3
# 19       2
# 16       2
# 28       2
# 13       2
# 31       2
# 29       2
# 22       2
# 26       2
# 42       1
# 39       1
# 23       1
# 35       1
# 38       1
# 51       1
# Name: V3745, dtype: int64
# Count of pandas missing values: 0
# V2331
# 0     8061
# 15       6
# 21       5
# 17       5
# 28       3
# 25       3
# ...

# %%
def check_vars (a_df, cols):
    """Pick n of the variables in the data frame and summarize values"""
    #cols = a_df.columns.tolist()
    #selection = np.random.randint(0, a_df.shape[1], n)
    #for idx in selection:
    #col = cols[idx]
    for col in cols:
        print(col)
        print(a_df[col].value_counts())
        print(f"Count of pandas missing values: {sum(a_df[col].isna())}")

# %%
check_vars(df, ['V1144'])
# Out:
# V1144
# 5    4201
# 0    3511
# 1     379
# 9       7
# Name: V1144, dtype: int64
# Count of pandas missing values: 0

# %%
check
